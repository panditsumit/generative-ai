# %% [markdown]
# <h1>Basic Food Agent using Microsoft Framework</h1>
# This notebook demonstrates how to build basic food agent. Try different cuisines using microsoft agent framework.
# Here we will use OpenRouter API to build the basic food Agents

# %% [markdown]
# <h3> Setup and Installations</h3>
# <ul>
# <li> Install Required Dependencies </li>
# <li> Get the OpenRouter API Key from https://openrouter.ai/settings/keys </li>
# <li> Load the OpenRouter API Key from the Environment Variables .env file</li>
# </ul>

# %% [markdown]
# # Installing required Dependencies

# %%
# install dotenv to load .env file
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (1.2.1)

# %%
# !pip install -U agent-framework --pre
# Out:
# Requirement already satisfied: agent-framework in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (1.0.0b260116)
# Requirement already satisfied: agent-framework-core==1.0.0b260116 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: typing-extensions in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.12.5)
# Requirement already satisfied: pydantic-settings<3,>=2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.15.0)
# Requirement already satisfied: azure-identity<2,>=1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.26.0b1)
# Requirement already satisfied: mcp<2,>=1.24.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.25.0)
# Requirement already satisfied: packaging>=24.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (25.0)
# Requirement already satisfied: agent-framework-a2a in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-ag-ui in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-azure-ai-search in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-anthropic in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-azure-ai in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-azurefunctions in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-chatkit in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-copilotstudio in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260107)
# Requirement already satisfied: agent-framework-declarative in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-devui in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-lab in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b251024)
# Requirement already satisfied: agent-framework-mem0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-ollama in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-purview in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: agent-framework-redis in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.0b260116)
# Requirement already satisfied: azure-core>=1.31.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.38.0)
# Requirement already satisfied: cryptography>=2.5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.35.0b1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (4.26.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.50.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.40.0)
# Requirement already satisfied: websockets>=15.0.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.41.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from pydantic-settings<3,>=2->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.2.1)
# Requirement already satisfied: idna>=2.8 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from anyio>=4.5->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.11)
# Requirement already satisfied: requests>=2.21.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.0.0)
# Requirement already satisfied: pycparser in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.23)
# Requirement already satisfied: certifi in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.6.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.12.0)
# Requirement already satisfied: sniffio in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from opentelemetry-api>=1.39.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.60b1)
# Requirement already satisfied: click>=7.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core==1.0.0b260116->agent-framework-core[all]==1.0.0b260116->agent-framework) (8.3.1)
# Requirement already satisfied: a2a-sdk>=0.3.5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.3.22)
# Requirement already satisfied: google-api-core>=1.26.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.29.0)
# Requirement already satisfied: protobuf>=5.29.5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (5.29.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.72.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.27.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.47.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.6.2)
# Requirement already satisfied: ag-ui-protocol>=0.1.9 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.1.10)
# Requirement already satisfied: fastapi>=0.115.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.128.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from fastapi>=0.115.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.0.4)
# Requirement already satisfied: anthropic<1,>=0.70.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-anthropic->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.76.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.17.0)
# Requirement already satisfied: azure-ai-projects>=2.0.0b2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.0.0b3)
# Requirement already satisfied: azure-ai-agents==1.2.0b5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.2.0b5)
# Requirement already satisfied: aiohttp in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.13.3)
# Requirement already satisfied: isodate>=0.6.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.7.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-ai-projects>=2.0.0b2->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (12.28.0)
# Requirement already satisfied: azure-search-documents==11.7.0b2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-azure-ai-search->agent-framework-core[all]==1.0.0b260116->agent-framework) (11.7.0b2)
# Requirement already satisfied: azure-common>=1.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-search-documents==11.7.0b2->agent-framework-azure-ai-search->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.1.28)
# Requirement already satisfied: azure-functions in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.25.0b3.dev1)
# Requirement already satisfied: azure-functions-durable in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.4.0)
# Requirement already satisfied: openai-chatkit<2.0.0,>=1.4.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-chatkit->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.5.3)
# Requirement already satisfied: openai-agents>=0.3.2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.6.9)
# Requirement already satisfied: jinja2<4,>=3.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from jinja2<4,>=3.1->openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.0.3)
# Requirement already satisfied: griffe<2,>=1.5.6 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.15.0)
# Requirement already satisfied: types-requests<3,>=2.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.32.4.20260107)
# Requirement already satisfied: colorama>=0.4 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from griffe<2,>=1.5.6->openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.0->agent-framework-chatkit->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.4.6)
# Requirement already satisfied: microsoft-agents-copilotstudio-client>=0.3.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-copilotstudio->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.7.0.dev12)
# Requirement already satisfied: microsoft-agents-hosting-core==0.7.0.dev12 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.7.0.dev12)
# Requirement already satisfied: microsoft-agents-activity==0.7.0.dev12 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from microsoft-agents-hosting-core==0.7.0.dev12->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.7.0.dev12)
# Requirement already satisfied: powerfx>=0.0.31 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-declarative->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.0.34)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-declarative->agent-framework-core[all]==1.0.0b260116->agent-framework) (6.0.3)
# Requirement already satisfied: pythonnet==3.0.5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from powerfx>=0.0.31->agent-framework-declarative->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.0.5)
# Requirement already satisfied: clr_loader<0.3.0,>=0.2.7 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from pythonnet==3.0.5->powerfx>=0.0.31->agent-framework-declarative->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.2.10)
# Requirement already satisfied: httptools>=0.6.3 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.1.1)
# Requirement already satisfied: mem0ai>=1.0.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.2)
# Requirement already satisfied: posthog>=3.5.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (7.6.0)
# Requirement already satisfied: pytz>=2024.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.16.2)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.0.45)
# Requirement already satisfied: six>=1.5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from posthog>=3.5.0->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from posthog>=3.5.0->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from posthog>=3.5.0->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.2.1)
# Requirement already satisfied: grpcio>=1.41.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from qdrant-client>=1.9.1->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.78.0rc2)
# Requirement already satisfied: numpy>=2.1.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from qdrant-client>=1.9.1->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.4.1)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from qdrant-client>=1.9.1->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (4.1.0)
# Requirement already satisfied: greenlet>=1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from sqlalchemy>=2.0.31->mem0ai>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.3.0)
# Requirement already satisfied: ollama>=0.5.3 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-ollama->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.6.1)
# Requirement already satisfied: redis>=6.4.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.0b260116->agent-framework) (7.1.0)
# Requirement already satisfied: redisvl>=0.8.2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.13.2)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.5.4)
# Requirement already satisfied: python-ulid>=3.0.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b260116->agent-framework) (9.1.2)
# Requirement already satisfied: ply in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from jsonpath-ng>=1.5.0->redisvl>=0.8.2->agent-framework-redis->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.11)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from aiohttp->agent-framework-azure-ai->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.22.0)
# Requirement already satisfied: werkzeug~=3.1.3 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-functions->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b260116->agent-framework) (3.1.5)
# Requirement already satisfied: furl>=2.1.0 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from azure-functions-durable->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b260116->agent-framework) (2.1.4)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /home/rancore/github/generative-ai/.venv/lib/python3.13/site-packages (from furl>=2.1.0->azure-functions-durable->agent-framework-azurefunctions->agent-framework-core[all]==1.0.0b260116->agent-framework) (1.0.2)

# %%
""" 
Add in .env file
OPENROUTER_API_KEY=skf_
OPENROUTER_ENDPOINT=https://openrouter.ai/api/v1
"""
# Out:
# ' \nAdd in .env file\nOPENROUTER_API_KEY=skf_\nOPENROUTER_ENDPOINT=https://openrouter.ai/api/v1\n'

# %%
# Import Required Libraries
import os
import random
# load dotenv library
from dotenv import load_dotenv, find_dotenv

# %%
# Import Microsoft Agent Framework components
# ChatAgent : The main Agent class of the Conversational AI
# OpenAIChatClient - Client for loading llm_inference, here we will use OPENROUTER instead of OPENAI
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# load the environment variables, this loads .env file from the project
load_dotenv(find_dotenv())
# Out:
# True

# %%
cuisines = (
    ("Italian", ["Pizza Margherita", "Pasta Carbonara", "Lasagna"]),
    ("Chinese", ["Kung Pao Chicken", "Sweet and Sour Pork", "Spring Rolls"]),
    ("Indian", ["Butter Chicken", "Paneer Tikka", "Biryani"]),
    ("Mexican", ["Tacos", "Enchiladas", "Guacamole"]),
    ("Japanese", ["Sushi", "Ramen", "Tempura"]),
    ("Thai", ["Pad Thai", "Green Curry", "Tom Yum Soup"]),
    ("French", ["Croissant", "Coq au Vin", "Ratatouille"]),
    ("Greek", ["Moussaka", "Souvlaki", "Greek Salad"]),
    ("Spanish", ["Paella", "Tapas", "Churros"]),
    ("Korean", ["Bibimbap", "Kimchi", "Bulgogi"]),
    ("Turkish", ["Kebabs", "Baklava", "Meze"]),
    ("Vietnamese", ["Pho", "Banh Mi", "Spring Rolls"]),
    ("Lebanese", ["Hummus", "Falafel", "Tabbouleh"]),
    ("Moroccan", ["Tagine", "Couscous", "Pastilla"]),
    ("American", ["Burger", "Fried Chicken", "Mac and Cheese"])
)

def get_random_cuisines():
    """ Get a random dish to Try

    Returns: 
        str: A randomly selected dish from our predefined menu
    """
    cuisine, dishes = random.choice(cuisines)
    dish = random.choice(dishes)
    # Return in a structured, tool-friendly format
    # Returns a random dish from the tuples
    return {
        "cuisine": cuisine,
        "dish": dish,
        "all_examples": dishes
    }
print(get_random_cuisines())
# Out:
# {'cuisine': 'Thai', 'dish': 'Green Curry', 'all_examples': ['Pad Thai', 'Green Curry', 'Tom Yum Soup']}

# %%
# Create OPEN AI Chat Client for OpenRouter Models
# This client connects to the OpenRouter Models which are OpenAI-compatible endpoint
# Environment variables required
# OPENROUTER_ENDPOINT - 
# OPENROUTER_API_KEY
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("OPENROUTER_ENDPOINT"),
    api_key=os.environ.get("OPENROUTER_API_KEY"),
    model_id="nvidia/nemotron-3-nano-30b-a3b:free"
)

# %%
# Create the Food Suggestion Agent
# This creates a conversation AI agent with specific capabilities
# -chat_client: AI model client for generating response( llm_inference in short)
# -instructions: system_prompt that defines the agent personality and role
# -tools: list of functions the agent can call to perform actions
agent = ChatAgent(
    chat_client=openai_chat_client,
    instructions="You are an helpful AI Agent that helps customers decides random cuisines to try",
    tools=[get_random_cuisines]
)

# %%
# Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_cuisines) if needed
response = await agent.run("Suggest me something to eat today")

# %%
# View the raw response object, 
# this helps understands the structure of the response including metadata
response

# %%
# Extract and Display the message
last_message = response.messages[-1]
# let's get the text content from the message
text_content = last_message.contents[0].text
print("Food Cuising: ")
print(text_content)
# Out:
# Food Cuising:
# How about trying **Falafel** from Lebanese cuisine? It's a popular Middle Eastern dish made from ground chickpeas or fava beans, typically served in pita bread with tahini sauce. If you're curious, you could also explore other Lebanese dishes like Hummus or Tabbouleh! 😊
